# %%
import torch
import torch.nn as nn
from torch.utils.data import Subset, DataLoader
from sklearn.model_selection import StratifiedKFold
import numpy as np


from dataset import create_dataloaders
from tcn_model import MEGTCN
from train import train_one_epoch
from evaluate import evaluate
from grid_search import run_grid_search

# %%
DATA_DIR = "preprocessed_data/Intra"
BATCH_SIZE = 8
EPOCHS = 30
LEARNING_RATE = 1e-3
NUM_CLASSES = 4
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {DEVICE}")
# Out:
# Using device: cuda

# %%
train_loader, test_loader = create_dataloaders(DATA_DIR, BATCH_SIZE)
# Out:
# Loading test data...
# Loading train data...
# Loaded 32 training samples
# Loaded 8 test samples
# Class distribution in training: [8 8 8 8]
# Class distribution in test: [2 2 2 2]
# Train batches: 4
# Test batches: 1

# %%
# K-fold cross-validation with stratification
dataset = train_loader.dataset
k_folds = 4

# Get labels from dataset
labels = np.array([dataset[i][1] for i in range(len(dataset))])

# Stratified k-fold split
skf = StratifiedKFold(n_splits=k_folds, shuffle=True, random_state=42)

for fold, (train_idx, val_idx) in enumerate(skf.split(np.zeros(len(dataset)), labels)):
    fold_train_loader = DataLoader(Subset(dataset, train_idx), batch_size=BATCH_SIZE, shuffle=True)
    val_loader = DataLoader(Subset(dataset, val_idx), batch_size=BATCH_SIZE, shuffle=False)

    model = MEGTCN(num_classes=NUM_CLASSES).to(DEVICE)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

    print(f"Starting fold {fold+1}/{k_folds}")
    for epoch in range(EPOCHS):
        train_loss, train_acc = train_one_epoch(model, fold_train_loader, criterion, optimizer, DEVICE)
        val_loss, val_acc = evaluate(model, val_loader, criterion, DEVICE)

        print(
            f"Fold {fold+1} | Epoch {epoch+1}/{EPOCHS} | "
            f"Train Acc: {train_acc:.2f}% | Val Acc: {val_acc:.2f}%"
        )
# Out:
# Starting fold 1/4
# Number of testing samples in fold 1: 8
# Fold 1 | Epoch 1/30 | Train Acc: 50.00% | Val Acc: 87.50%
# Number of testing samples in fold 1: 8
# Fold 1 | Epoch 2/30 | Train Acc: 87.50% | Val Acc: 100.00%
# Number of testing samples in fold 1: 8
# Fold 1 | Epoch 3/30 | Train Acc: 100.00% | Val Acc: 100.00%
# Number of testing samples in fold 1: 8
# Fold 1 | Epoch 4/30 | Train Acc: 87.50% | Val Acc: 100.00%
# Number of testing samples in fold 1: 8
# Fold 1 | Epoch 5/30 | Train Acc: 91.67% | Val Acc: 100.00%
# Number of testing samples in fold 1: 8
# Fold 1 | Epoch 6/30 | Train Acc: 100.00% | Val Acc: 100.00%
# Number of testing samples in fold 1: 8
# Fold 1 | Epoch 7/30 | Train Acc: 100.00% | Val Acc: 100.00%
# Number of testing samples in fold 1: 8
# Fold 1 | Epoch 8/30 | Train Acc: 100.00% | Val Acc: 100.00%
# Number of testing samples in fold 1: 8
# Fold 1 | Epoch 9/30 | Train Acc: 95.83% | Val Acc: 100.00%
# Number of testing samples in fold 1: 8
# Fold 1 | Epoch 10/30 | Train Acc: 95.83% | Val Acc: 100.00%
# Number of testing samples in fold 1: 8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 27
#      23     print(f"Starting fold {fold+1}/{k_folds}")
#      24     for epoch in range(EPOCHS):
#      25         train_loss, train_acc = train_one_epoch(model, fold_train_loader, criterion, optimizer, DEVICE)
#      26         print(f"Number of testing samples in fold {fold+1}: {len(val_loader.dataset)}")
# ---> 27         val_loss, val_acc = evaluate(model, val_loader, criterion, DEVICE)
#      28
#      29         print(
#      30             f"Fold {fold+1} | Epoch {epoch+1}/{EPOCHS} | "
#
# File c:\Users\joybo\Documents\Repos\DL\DeepLearning\Assignment 2\evaluate.py:12, in evaluate(model, loader, criterion, device)
#       9 correct = 0
#      10 total = 0
# ---> 12 with torch.no_grad():
#      13     for x, y in loader:
#      15         x = x.to(device)
#
# File c:\Users\joybo\Documents\Repos\DL\DeepLearning\.venv\Lib\site-packages\torch\utils\data\dataloader.py:741, in _BaseDataLoaderIter.__next__(self)
#     738 if self._sampler_iter is None:
#     739     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     740     self._reset()  # type: ignore[call-arg]
# --> 741 data = self._next_data()
#     742 self._num_yielded += 1
#     743 if (
#     744     self._dataset_kind == _DatasetKind.Iterable
#     745     and self._IterableDataset_len_called is not None
#     746     and self._num_yielded > self._IterableDataset_len_called
#     747 ):
#
# File c:\Users\joybo\Documents\Repos\DL\DeepLearning\.venv\Lib\site-packages\torch\utils\data\dataloader.py:801, in _SingleProcessDataLoaderIter._next_data(self)
#     799 def _next_data(self):
#     800     index = self._next_index()  # may raise StopIteration
# --> 801     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     802     if self._pin_memory:
#     803         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\joybo\Documents\Repos\DL\DeepLearning\.venv\Lib\site-packages\torch\utils\data\_utils\fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50 if self.auto_collation:
#      51     if hasattr(self.dataset, "__getitems__") and self.dataset.__getitems__:
# ---> 52         data = self.dataset.__getitems__(possibly_batched_index)
#      53     else:
#      54         data = [self.dataset[idx] for idx in possibly_batched_index]
#
# File c:\Users\joybo\Documents\Repos\DL\DeepLearning\.venv\Lib\site-packages\torch\utils\data\dataset.py:443, in Subset.__getitems__(self, indices)
#     441     return self.dataset.__getitems__([self.indices[idx] for idx in indices])  # type: ignore[attr-defined]
#     442 else:
# --> 443     return [self.dataset[self.indices[idx]] for idx in indices]
#
# File c:\Users\joybo\Documents\Repos\DL\DeepLearning\Assignment 2\dataset.py:21, in MEGDataset.__getitem__(self, idx)
#      19 def __getitem__(self, idx):
# ---> 21     x = pd.read_csv(self.file_paths[idx], index_col=0,).values.astype(np.float32)
#      23     # CSV shape: (time, sensors)
#      24     x = x.T # Convert to: (sensors, time)
#
# File c:\Users\joybo\Documents\Repos\DL\DeepLearning\.venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\joybo\Documents\Repos\DL\DeepLearning\.venv\Lib\site-packages\pandas\io\parsers\readers.py:306, in _read(filepath_or_buffer, kwds)
#     303     return parser
#     305 with parser:
# --> 306     return parser.read(nrows)
#
# File c:\Users\joybo\Documents\Repos\DL\DeepLearning\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1947, in TextFileReader.read(self, nrows)
#    1940 nrows = validate_integer("nrows", nrows)
#    1941 try:
#    1942     # error: "ParserBase" has no attribute "read"
#    1943     (
#    1944         index,
#    1945         columns,
#    1946         col_dict,
# -> 1947     ) = self._engine.read(  # type: ignore[attr-defined]
#    1948         nrows
#    1949     )
#    1950 except Exception:
#    1951     self.close()
#
# File c:\Users\joybo\Documents\Repos\DL\DeepLearning\.venv\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:215, in CParserWrapper.read(self, nrows)
#     213 try:
#     214     if self.low_memory:
# --> 215         chunks = self._reader.read_low_memory(nrows)
#     216         # destructive to chunks
#     217         data = _concatenate_chunks(chunks, self.names)
#
# File pandas/_libs/parsers.pyx:832, in pandas._libs.parsers.TextReader.read_low_memory()
# --> 832 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/parsers.pyx:897, in pandas._libs.parsers.TextReader._read_rows()
# --> 897 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/parsers.pyx:868, in pandas._libs.parsers.TextReader._tokenize_rows()
# --> 868 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/parsers.pyx:885, in pandas._libs.parsers.TextReader._check_tokenize_status()
# --> 885 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/parsers.pyx:2076, in pandas._libs.parsers.raise_parser_error()
# -> 2076 'Could not get source, probably due dynamically evaluated source code.'
#
# File <frozen codecs>:331, in BufferedIncrementalDecoder.getstate(self)
# --> 331 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyboardInterrupt:

# %%
run_grid_search(train_loader, test_loader, NUM_CLASSES, epochs=15)
# Out:
# ====================================
# Testing parameters:
# {'learning_rate': 0.001, 'kernel_size': 3, 'dropout': 0.2, 'hidden_channels': 32}
# ====================================
# Epoch 1/15 | Train Acc: 50.00% | Val Acc: 50.00%
# Epoch 2/15 | Train Acc: 90.62% | Val Acc: 50.00%
# Epoch 3/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 4/15 | Train Acc: 93.75% | Val Acc: 100.00%
# Epoch 5/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 6/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 7/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 8/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 9/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 10/15 | Train Acc: 90.62% | Val Acc: 100.00%
# Epoch 11/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 12/15 | Train Acc: 93.75% | Val Acc: 100.00%
# Epoch 13/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 14/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 15/15 | Train Acc: 90.62% | Val Acc: 100.00%
#
# ====================================
# Testing parameters:
# {'learning_rate': 0.001, 'kernel_size': 3, 'dropout': 0.2, 'hidden_channels': 64}
# ====================================
# Epoch 1/15 | Train Acc: 78.12% | Val Acc: 100.00%
# Epoch 2/15 | Train Acc: 96.88% | Val Acc: 100.00%
# Epoch 3/15 | Train Acc: 96.88% | Val Acc: 100.00%
# Epoch 4/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 5/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 6/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 7/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 8/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 9/15 | Train Acc: 90.62% | Val Acc: 100.00%
# Epoch 10/15 | Train Acc: 93.75% | Val Acc: 100.00%
# Epoch 11/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 12/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 13/15 | Train Acc: 96.88% | Val Acc: 100.00%
# Epoch 14/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 15/15 | Train Acc: 96.88% | Val Acc: 100.00%
#
# ====================================
# Testing parameters:
# {'learning_rate': 0.001, 'kernel_size': 3, 'dropout': 0.5, 'hidden_channels': 32}
# ====================================
# Epoch 1/15 | Train Acc: 34.38% | Val Acc: 50.00%
# Epoch 2/15 | Train Acc: 53.12% | Val Acc: 50.00%
# Epoch 3/15 | Train Acc: 68.75% | Val Acc: 100.00%
# Epoch 4/15 | Train Acc: 90.62% | Val Acc: 100.00%
# Epoch 5/15 | Train Acc: 90.62% | Val Acc: 100.00%
# Epoch 6/15 | Train Acc: 93.75% | Val Acc: 100.00%
# Epoch 7/15 | Train Acc: 96.88% | Val Acc: 100.00%
# Epoch 8/15 | Train Acc: 96.88% | Val Acc: 100.00%
# Epoch 9/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 10/15 | Train Acc: 96.88% | Val Acc: 100.00%
# Epoch 11/15 | Train Acc: 90.62% | Val Acc: 100.00%
# Epoch 12/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 13/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 14/15 | Train Acc: 96.88% | Val Acc: 100.00%
# Epoch 15/15 | Train Acc: 96.88% | Val Acc: 100.00%
#
# ====================================
# Testing parameters:
# {'learning_rate': 0.001, 'kernel_size': 3, 'dropout': 0.5, 'hidden_channels': 64}
# ====================================
# Epoch 1/15 | Train Acc: 50.00% | Val Acc: 100.00%
# Epoch 2/15 | Train Acc: 87.50% | Val Acc: 100.00%
# Epoch 3/15 | Train Acc: 93.75% | Val Acc: 100.00%
# Epoch 4/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 5/15 | Train Acc: 87.50% | Val Acc: 100.00%
# Epoch 6/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 7/15 | Train Acc: 96.88% | Val Acc: 100.00%
# Epoch 8/15 | Train Acc: 93.75% | Val Acc: 100.00%
# Epoch 9/15 | Train Acc: 90.62% | Val Acc: 100.00%
# Epoch 10/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 11/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 12/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 13/15 | Train Acc: 93.75% | Val Acc: 100.00%
# Epoch 14/15 | Train Acc: 96.88% | Val Acc: 100.00%
# Epoch 15/15 | Train Acc: 96.88% | Val Acc: 100.00%
#
# ====================================
# Testing parameters:
# {'learning_rate': 0.001, 'kernel_size': 7, 'dropout': 0.2, 'hidden_channels': 32}
# ====================================
# Epoch 1/15 | Train Acc: 56.25% | Val Acc: 100.00%
# Epoch 2/15 | Train Acc: 93.75% | Val Acc: 100.00%
# Epoch 3/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 4/15 | Train Acc: 96.88% | Val Acc: 100.00%
# Epoch 5/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 6/15 | Train Acc: 90.62% | Val Acc: 100.00%
# Epoch 7/15 | Train Acc: 96.88% | Val Acc: 100.00%
# Epoch 8/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 9/15 | Train Acc: 96.88% | Val Acc: 100.00%
# Epoch 10/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 11/15 | Train Acc: 96.88% | Val Acc: 100.00%
# Epoch 12/15 | Train Acc: 96.88% | Val Acc: 100.00%
# Epoch 13/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 14/15 | Train Acc: 96.88% | Val Acc: 100.00%
# Epoch 15/15 | Train Acc: 100.00% | Val Acc: 100.00%
#
# ====================================
# Testing parameters:
# {'learning_rate': 0.001, 'kernel_size': 7, 'dropout': 0.2, 'hidden_channels': 64}
# ====================================
# Epoch 1/15 | Train Acc: 71.88% | Val Acc: 100.00%
# Epoch 2/15 | Train Acc: 93.75% | Val Acc: 100.00%
# Epoch 3/15 | Train Acc: 96.88% | Val Acc: 100.00%
# Epoch 4/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 5/15 | Train Acc: 96.88% | Val Acc: 100.00%
# Epoch 6/15 | Train Acc: 96.88% | Val Acc: 100.00%
# Epoch 7/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 8/15 | Train Acc: 96.88% | Val Acc: 75.00%
# Epoch 9/15 | Train Acc: 90.62% | Val Acc: 100.00%
# Epoch 10/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 11/15 | Train Acc: 96.88% | Val Acc: 100.00%
# Epoch 12/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 13/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 14/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 15/15 | Train Acc: 96.88% | Val Acc: 100.00%
#
# ====================================
# Testing parameters:
# {'learning_rate': 0.001, 'kernel_size': 7, 'dropout': 0.5, 'hidden_channels': 32}
# ====================================
# Epoch 1/15 | Train Acc: 50.00% | Val Acc: 50.00%
# Epoch 2/15 | Train Acc: 65.62% | Val Acc: 75.00%
# Epoch 3/15 | Train Acc: 90.62% | Val Acc: 100.00%
# Epoch 4/15 | Train Acc: 84.38% | Val Acc: 100.00%
# Epoch 5/15 | Train Acc: 93.75% | Val Acc: 100.00%
# Epoch 6/15 | Train Acc: 90.62% | Val Acc: 100.00%
# Epoch 7/15 | Train Acc: 93.75% | Val Acc: 100.00%
# Epoch 8/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 9/15 | Train Acc: 96.88% | Val Acc: 100.00%
# Epoch 10/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 11/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 12/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 13/15 | Train Acc: 93.75% | Val Acc: 100.00%
# Epoch 14/15 | Train Acc: 96.88% | Val Acc: 100.00%
# Epoch 15/15 | Train Acc: 100.00% | Val Acc: 100.00%
#
# ====================================
# Testing parameters:
# {'learning_rate': 0.001, 'kernel_size': 7, 'dropout': 0.5, 'hidden_channels': 64}
# ====================================
# Epoch 1/15 | Train Acc: 53.12% | Val Acc: 100.00%
# Epoch 2/15 | Train Acc: 96.88% | Val Acc: 100.00%
# Epoch 3/15 | Train Acc: 93.75% | Val Acc: 100.00%
# Epoch 4/15 | Train Acc: 93.75% | Val Acc: 100.00%
# Epoch 5/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 6/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 7/15 | Train Acc: 93.75% | Val Acc: 100.00%
# Epoch 8/15 | Train Acc: 96.88% | Val Acc: 100.00%
# Epoch 9/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 10/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 11/15 | Train Acc: 87.50% | Val Acc: 100.00%
# Epoch 12/15 | Train Acc: 96.88% | Val Acc: 100.00%
# Epoch 13/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 14/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 15/15 | Train Acc: 93.75% | Val Acc: 100.00%
#
# ====================================
# Testing parameters:
# {'learning_rate': 0.001, 'kernel_size': 15, 'dropout': 0.2, 'hidden_channels': 32}
# ====================================
# Epoch 1/15 | Train Acc: 65.62% | Val Acc: 50.00%
# Epoch 2/15 | Train Acc: 90.62% | Val Acc: 100.00%
# Epoch 3/15 | Train Acc: 93.75% | Val Acc: 100.00%
# Epoch 4/15 | Train Acc: 90.62% | Val Acc: 100.00%
# Epoch 5/15 | Train Acc: 96.88% | Val Acc: 100.00%
# Epoch 6/15 | Train Acc: 93.75% | Val Acc: 100.00%
# Epoch 7/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 8/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 9/15 | Train Acc: 96.88% | Val Acc: 100.00%
# Epoch 10/15 | Train Acc: 96.88% | Val Acc: 100.00%
# Epoch 11/15 | Train Acc: 90.62% | Val Acc: 100.00%
# Epoch 12/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 13/15 | Train Acc: 100.00% | Val Acc: 100.00%
# Epoch 14/15 | Train Acc: 96.88% | Val Acc: 100.00%
# Epoch 15/15 | Train Acc: 100.00% | Val Acc: 87.50%
#
# ====================================
# Testing parameters:
# {'learning_rate': 0.001, 'kernel_size': 15, 'dropout': 0.2, 'hidden_channels': 64}
# ====================================
# Epoch 1/15 | Train Acc: 62.50% | Val Acc: 75.00%
# Epoch 2/15 | Train Acc: 96.88% | Val Acc: 100.00%

# %% [markdown]
# ### Cross Dataset

# %%
DATA_DIR = "preprocessed_data/Cross"
BATCH_SIZE = 8
EPOCHS = 30
LEARNING_RATE = 1e-3
NUM_CLASSES = 4
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {DEVICE}")

cross_train_loader, cross_test_loader = create_dataloaders(DATA_DIR, BATCH_SIZE)
# Out:
# Using device: cuda
# Loading test1 data...
# Loading test2 data...
# Loading test3 data...
# Loading train data...
# Loaded 64 training samples
# Loaded 48 test samples
# Class distribution in training: [16 16 16 16]
# Class distribution in test: [12 12 12 12]
# Train batches: 8
# Test batches: 6

# %%
# TODO: make sure both people are represented in the different folds on top of task representation
# K-fold cross-validation with stratification
cross_dataset = cross_train_loader.dataset
k_folds = 4

# Get labels from dataset
labels = np.array([cross_dataset[i][1] for i in range(len(cross_dataset))])

# Stratified k-fold split
skf = StratifiedKFold(n_splits=k_folds, shuffle=True, random_state=42)

for fold, (train_idx, val_idx) in enumerate(skf.split(np.zeros(len(cross_dataset)), labels)):
    fold_train_loader = DataLoader(Subset(cross_dataset, train_idx), batch_size=BATCH_SIZE, shuffle=True)
    val_loader = DataLoader(Subset(cross_dataset, val_idx), batch_size=BATCH_SIZE, shuffle=False)

    model = MEGTCN(num_classes=NUM_CLASSES).to(DEVICE)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

    print(f"Starting fold {fold+1}/{k_folds}")
    for epoch in range(EPOCHS):
        train_loss, train_acc = train_one_epoch(model, fold_train_loader, criterion, optimizer, DEVICE)
        val_loss, val_acc = evaluate(model, val_loader, criterion, DEVICE)

        print(
            f"Fold {fold+1} | Epoch {epoch+1}/{EPOCHS} | "
            f"Train Acc: {train_acc:.2f}% | Val Acc: {val_acc:.2f}%"
        )

# %%
run_grid_search(cross_train_loader, cross_test_loader, NUM_CLASSES, epochs=15)
# Out:
# ====================================
# Testing parameters:
# {'learning_rate': 0.001, 'kernel_size': 3, 'dropout': 0.2, 'hidden_channels': 32}
# ====================================
# Epoch 1/15 | Train Acc: 57.81% | Val Acc: 50.00%
# Epoch 2/15 | Train Acc: 84.38% | Val Acc: 52.08%
# Epoch 3/15 | Train Acc: 87.50% | Val Acc: 70.83%
# Epoch 4/15 | Train Acc: 93.75% | Val Acc: 64.58%
# Epoch 5/15 | Train Acc: 100.00% | Val Acc: 64.58%
# Epoch 6/15 | Train Acc: 100.00% | Val Acc: 58.33%
# Epoch 7/15 | Train Acc: 98.44% | Val Acc: 50.00%
# Epoch 8/15 | Train Acc: 96.88% | Val Acc: 60.42%
# Epoch 9/15 | Train Acc: 100.00% | Val Acc: 64.58%
# Epoch 10/15 | Train Acc: 96.88% | Val Acc: 66.67%
# Epoch 11/15 | Train Acc: 96.88% | Val Acc: 72.92%
# Epoch 12/15 | Train Acc: 95.31% | Val Acc: 66.67%
# Epoch 13/15 | Train Acc: 90.62% | Val Acc: 62.50%
# Epoch 14/15 | Train Acc: 93.75% | Val Acc: 66.67%
# Epoch 15/15 | Train Acc: 95.31% | Val Acc: 62.50%
#
# ====================================
# Testing parameters:
# {'learning_rate': 0.001, 'kernel_size': 3, 'dropout': 0.2, 'hidden_channels': 64}
# ====================================
# Epoch 1/15 | Train Acc: 43.75% | Val Acc: 45.83%
# Epoch 2/15 | Train Acc: 85.94% | Val Acc: 60.42%
# Epoch 3/15 | Train Acc: 95.31% | Val Acc: 64.58%
# Epoch 4/15 | Train Acc: 89.06% | Val Acc: 58.33%
# Epoch 5/15 | Train Acc: 98.44% | Val Acc: 56.25%
# Epoch 6/15 | Train Acc: 98.44% | Val Acc: 54.17%
# Epoch 7/15 | Train Acc: 87.50% | Val Acc: 43.75%
# Epoch 8/15 | Train Acc: 100.00% | Val Acc: 45.83%
# Epoch 9/15 | Train Acc: 96.88% | Val Acc: 58.33%
# Epoch 10/15 | Train Acc: 93.75% | Val Acc: 64.58%
# Epoch 11/15 | Train Acc: 90.62% | Val Acc: 68.75%
# Epoch 12/15 | Train Acc: 96.88% | Val Acc: 64.58%
# Epoch 13/15 | Train Acc: 100.00% | Val Acc: 62.50%
# Epoch 14/15 | Train Acc: 98.44% | Val Acc: 66.67%
# Epoch 15/15 | Train Acc: 100.00% | Val Acc: 68.75%
#
# ====================================
# Testing parameters:
# {'learning_rate': 0.001, 'kernel_size': 3, 'dropout': 0.5, 'hidden_channels': 32}
# ====================================
# Epoch 1/15 | Train Acc: 42.19% | Val Acc: 39.58%
# Epoch 2/15 | Train Acc: 64.06% | Val Acc: 52.08%
# Epoch 3/15 | Train Acc: 79.69% | Val Acc: 56.25%
# Epoch 4/15 | Train Acc: 95.31% | Val Acc: 56.25%
# Epoch 5/15 | Train Acc: 93.75% | Val Acc: 68.75%
# Epoch 6/15 | Train Acc: 93.75% | Val Acc: 56.25%
# Epoch 7/15 | Train Acc: 95.31% | Val Acc: 64.58%
# Epoch 8/15 | Train Acc: 89.06% | Val Acc: 68.75%
# Epoch 9/15 | Train Acc: 95.31% | Val Acc: 68.75%
# Epoch 10/15 | Train Acc: 98.44% | Val Acc: 68.75%
# Epoch 11/15 | Train Acc: 96.88% | Val Acc: 75.00%
# Epoch 12/15 | Train Acc: 96.88% | Val Acc: 66.67%
# Epoch 13/15 | Train Acc: 95.31% | Val Acc: 62.50%
# Epoch 14/15 | Train Acc: 96.88% | Val Acc: 66.67%
# Epoch 15/15 | Train Acc: 98.44% | Val Acc: 66.67%
#
# ====================================
# Testing parameters:
# {'learning_rate': 0.001, 'kernel_size': 3, 'dropout': 0.5, 'hidden_channels': 64}
# ====================================
# Epoch 1/15 | Train Acc: 46.88% | Val Acc: 54.17%
# Epoch 2/15 | Train Acc: 78.12% | Val Acc: 70.83%
# Epoch 3/15 | Train Acc: 90.62% | Val Acc: 56.25%
# Epoch 4/15 | Train Acc: 92.19% | Val Acc: 56.25%
# Epoch 5/15 | Train Acc: 95.31% | Val Acc: 68.75%
# Epoch 6/15 | Train Acc: 96.88% | Val Acc: 62.50%
# Epoch 7/15 | Train Acc: 93.75% | Val Acc: 50.00%
# Epoch 8/15 | Train Acc: 93.75% | Val Acc: 56.25%
# Epoch 9/15 | Train Acc: 92.19% | Val Acc: 62.50%
# Epoch 10/15 | Train Acc: 90.62% | Val Acc: 58.33%
# Epoch 11/15 | Train Acc: 93.75% | Val Acc: 66.67%
# Epoch 12/15 | Train Acc: 95.31% | Val Acc: 64.58%
# Epoch 13/15 | Train Acc: 98.44% | Val Acc: 64.58%
# Epoch 14/15 | Train Acc: 96.88% | Val Acc: 70.83%
# Epoch 15/15 | Train Acc: 100.00% | Val Acc: 72.92%
#
# ====================================
# Testing parameters:
# {'learning_rate': 0.001, 'kernel_size': 7, 'dropout': 0.2, 'hidden_channels': 32}
# ====================================
# Epoch 1/15 | Train Acc: 59.38% | Val Acc: 62.50%
# Epoch 2/15 | Train Acc: 78.12% | Val Acc: 68.75%
# Epoch 3/15 | Train Acc: 89.06% | Val Acc: 64.58%
# Epoch 4/15 | Train Acc: 92.19% | Val Acc: 64.58%
# Epoch 5/15 | Train Acc: 100.00% | Val Acc: 66.67%
# Epoch 6/15 | Train Acc: 93.75% | Val Acc: 64.58%
# Epoch 7/15 | Train Acc: 89.06% | Val Acc: 52.08%
# Epoch 8/15 | Train Acc: 96.88% | Val Acc: 66.67%
# Epoch 9/15 | Train Acc: 96.88% | Val Acc: 58.33%
# Epoch 10/15 | Train Acc: 92.19% | Val Acc: 54.17%
# Epoch 11/15 | Train Acc: 95.31% | Val Acc: 60.42%
# Epoch 12/15 | Train Acc: 95.31% | Val Acc: 64.58%
# Epoch 13/15 | Train Acc: 95.31% | Val Acc: 66.67%
# Epoch 14/15 | Train Acc: 100.00% | Val Acc: 66.67%
# Epoch 15/15 | Train Acc: 92.19% | Val Acc: 64.58%
#
# ====================================
# Testing parameters:
# {'learning_rate': 0.001, 'kernel_size': 7, 'dropout': 0.2, 'hidden_channels': 64}
# ====================================
# Epoch 1/15 | Train Acc: 71.88% | Val Acc: 54.17%
# Epoch 2/15 | Train Acc: 76.56% | Val Acc: 52.08%
# Epoch 3/15 | Train Acc: 92.19% | Val Acc: 58.33%
# Epoch 4/15 | Train Acc: 95.31% | Val Acc: 50.00%
# Epoch 5/15 | Train Acc: 89.06% | Val Acc: 60.42%
# Epoch 6/15 | Train Acc: 98.44% | Val Acc: 64.58%
# Epoch 7/15 | Train Acc: 98.44% | Val Acc: 60.42%
# Epoch 8/15 | Train Acc: 95.31% | Val Acc: 56.25%
# Epoch 9/15 | Train Acc: 95.31% | Val Acc: 62.50%
# Epoch 10/15 | Train Acc: 98.44% | Val Acc: 64.58%
# Epoch 11/15 | Train Acc: 100.00% | Val Acc: 60.42%
# Epoch 12/15 | Train Acc: 98.44% | Val Acc: 62.50%
# Epoch 13/15 | Train Acc: 95.31% | Val Acc: 60.42%
# Epoch 14/15 | Train Acc: 96.88% | Val Acc: 58.33%
# Epoch 15/15 | Train Acc: 98.44% | Val Acc: 68.75%
#
# ====================================
# Testing parameters:
# {'learning_rate': 0.001, 'kernel_size': 7, 'dropout': 0.5, 'hidden_channels': 32}
# ====================================
# Epoch 1/15 | Train Acc: 35.94% | Val Acc: 62.50%
# Epoch 2/15 | Train Acc: 73.44% | Val Acc: 70.83%
# Epoch 3/15 | Train Acc: 87.50% | Val Acc: 66.67%
# Epoch 4/15 | Train Acc: 89.06% | Val Acc: 66.67%
# Epoch 5/15 | Train Acc: 90.62% | Val Acc: 64.58%
# Epoch 6/15 | Train Acc: 92.19% | Val Acc: 64.58%
# Epoch 7/15 | Train Acc: 95.31% | Val Acc: 66.67%
# Epoch 8/15 | Train Acc: 96.88% | Val Acc: 68.75%
# Epoch 9/15 | Train Acc: 95.31% | Val Acc: 62.50%
# Epoch 10/15 | Train Acc: 92.19% | Val Acc: 68.75%
# Epoch 11/15 | Train Acc: 100.00% | Val Acc: 58.33%
# Epoch 12/15 | Train Acc: 98.44% | Val Acc: 60.42%
# Epoch 13/15 | Train Acc: 98.44% | Val Acc: 52.08%
# Epoch 14/15 | Train Acc: 100.00% | Val Acc: 58.33%
# Epoch 15/15 | Train Acc: 90.62% | Val Acc: 56.25%
#
# ====================================
# Testing parameters:
# {'learning_rate': 0.001, 'kernel_size': 7, 'dropout': 0.5, 'hidden_channels': 64}
# ====================================
# Epoch 1/15 | Train Acc: 65.62% | Val Acc: 60.42%
# Epoch 2/15 | Train Acc: 93.75% | Val Acc: 60.42%
# Epoch 3/15 | Train Acc: 79.69% | Val Acc: 66.67%
# Epoch 4/15 | Train Acc: 93.75% | Val Acc: 64.58%
# Epoch 5/15 | Train Acc: 89.06% | Val Acc: 60.42%
# Epoch 6/15 | Train Acc: 93.75% | Val Acc: 60.42%
# Epoch 7/15 | Train Acc: 98.44% | Val Acc: 66.67%
# Epoch 8/15 | Train Acc: 100.00% | Val Acc: 66.67%
# Epoch 9/15 | Train Acc: 95.31% | Val Acc: 58.33%
# Epoch 10/15 | Train Acc: 96.88% | Val Acc: 66.67%
# Epoch 11/15 | Train Acc: 96.88% | Val Acc: 64.58%
# Epoch 12/15 | Train Acc: 93.75% | Val Acc: 68.75%
# Epoch 13/15 | Train Acc: 90.62% | Val Acc: 58.33%
# Epoch 14/15 | Train Acc: 93.75% | Val Acc: 54.17%
# Epoch 15/15 | Train Acc: 95.31% | Val Acc: 58.33%
#
# ====================================
# Testing parameters:
# {'learning_rate': 0.001, 'kernel_size': 15, 'dropout': 0.2, 'hidden_channels': 32}
# ====================================
# Epoch 1/15 | Train Acc: 42.19% | Val Acc: 45.83%
# Epoch 2/15 | Train Acc: 84.38% | Val Acc: 56.25%
# Epoch 3/15 | Train Acc: 89.06% | Val Acc: 58.33%
# Epoch 4/15 | Train Acc: 89.06% | Val Acc: 58.33%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 run_grid_search(cross_train_loader, cross_test_loader, NUM_CLASSES, epochs=15)
#
# File c:\Users\morri\Documents\GitHub\DeepLearning\Assignment 2\grid_search.py:53, in run_grid_search(train_loader, test_loader, num_classes, epochs)
#      46 optimizer = torch.optim.Adam(
#      47     model.parameters(),
#      48     lr=params["learning_rate"],
#      49 )
#      51 for epoch in range(epochs):
# ---> 53     train_loss, train_acc = train_one_epoch(
#      54         model,
#      55         train_loader,
#      56         criterion,
#      57         optimizer,
#      58         DEVICE,
#      59     )
#      61     val_loss, val_acc = evaluate(
#      62         model,
#      63         test_loader,
#      64         criterion,
#      65         DEVICE,
#      66     )
#      68     print(
#      69         f"Epoch {epoch+1}/{epochs} | "
#      70         f"Train Acc: {train_acc:.2f}% | "
#      71         f"Val Acc: {val_acc:.2f}%"
#      72     )
#
# File c:\Users\morri\Documents\GitHub\DeepLearning\Assignment 2\train.py:11, in train_one_epoch(model, loader, criterion, optimizer, device)
#       8 correct = 0
#       9 total = 0
# ---> 11 for x, y in loader:
#      12     x = x.to(device)
#      13     y = y.to(device)
#
# File c:\Users\morri\Documents\GitHub\DeepLearning\DeepL\lib\site-packages\torch\utils\data\dataloader.py:701, in _BaseDataLoaderIter.__next__(self)
#     698 if self._sampler_iter is None:
#     699     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700     self._reset()  # type: ignore[call-arg]
# --> 701 data = self._next_data()
#     702 self._num_yielded += 1
#     703 if (
#     704     self._dataset_kind == _DatasetKind.Iterable
#     705     and self._IterableDataset_len_called is not None
#     706     and self._num_yielded > self._IterableDataset_len_called
#     707 ):
#
# File c:\Users\morri\Documents\GitHub\DeepLearning\DeepL\lib\site-packages\torch\utils\data\dataloader.py:757, in _SingleProcessDataLoaderIter._next_data(self)
#     755 def _next_data(self):
#     756     index = self._next_index()  # may raise StopIteration
# --> 757     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     758     if self._pin_memory:
#     759         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\morri\Documents\GitHub\DeepLearning\DeepL\lib\site-packages\torch\utils\data\_utils\fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File c:\Users\morri\Documents\GitHub\DeepLearning\DeepL\lib\site-packages\torch\utils\data\_utils\fetch.py:52, in <listcomp>(.0)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File c:\Users\morri\Documents\GitHub\DeepLearning\Assignment 2\dataset.py:21, in MEGDataset.__getitem__(self, idx)
#      19 def __getitem__(self, idx):
# ---> 21     x = pd.read_csv(self.file_paths[idx], index_col=0,).values.astype(np.float32)
#      23     # CSV shape: (time, sensors)
#      24     x = x.T # Convert to: (sensors, time)
#
# File c:\Users\morri\Documents\GitHub\DeepLearning\DeepL\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\morri\Documents\GitHub\DeepLearning\DeepL\lib\site-packages\pandas\io\parsers\readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File c:\Users\morri\Documents\GitHub\DeepLearning\DeepL\lib\site-packages\pandas\io\parsers\readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File c:\Users\morri\Documents\GitHub\DeepLearning\DeepL\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# KeyboardInterrupt:
