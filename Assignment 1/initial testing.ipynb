# %%
from scipy.io import loadmat
import pandas as pd
import numpy as np

data = loadmat('Xtrain.mat')

# %%
print(data.keys())  # see variables inside
df = pd.DataFrame(data['Xtrain'])
#df.describe()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'Xtrain'])

# %%
Xtrain = data['Xtrain']/255

import plotly.express as px

px.line(Xtrain)

# %%
def data_cleaning(df: pd.DataFrame) -> pd.DataFrame:
    normalized = df/255
    return normalized
    
def slices(s: pd.Series, slice_length) -> tuple[pd.Series, pd.Series]:
    slices = [window for window in s.rolling(window=slice_length+1)]
    res = [(slc.iloc[:-1], slc.iloc[-1]) for slc in slices[slice_length:]]
    return res

# %%
df = pd.Series(data['Xtrain'].flatten())
df = data_cleaning(df)
X, Y = zip(*slices(df, 12))
len(X)
# Out:
# 988

# %% [markdown]
# use dev set
# use simple regession model as baseline

# %%
from sklearn.linear_model import LinearRegression

clf = LinearRegression().fit(X[:500],Y[:500])
y_pred = clf.predict(X[500:])
print(clf.score(X= X[500:], y = Y[500:]))
px.line(zip(Y[500:], y_pred))
# Out:
# 0.7319740996720061

# %%
clf.__getstate__()
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'tol': 1e-06,
#  'n_jobs': None,
#  'positive': False,
#  'n_features_in_': 1,
#  'coef_': array([0.52227036]),
#  'rank_': 1,
#  'singular_': array([4.40160836]),
#  'intercept_': np.float64(0.11358841959152699),
#  '_sklearn_version': '1.8.0'}
