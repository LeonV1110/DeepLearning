# %%
# Imports
from scipy.io import loadmat
import pandas as pd
import numpy as np
import torch.nn as nn
import torch
import itertools
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
data = loadmat('Xtrain.mat')

# %%
def data_cleaning(df: pd.DataFrame) -> pd.DataFrame:
    normalized = df/255
    return normalized
    
def slices(s: pd.Series, slice_length) -> tuple[pd.Series, pd.Series]:
    slices = [window for window in s.rolling(window=slice_length+1)]
    res = [(slc.iloc[:-1], slc.iloc[-1]) for slc in slices[slice_length:]]
    return res

# %%
def recursive_predict(model, start_window, steps=200):
    model.eval() # set model to evaluation mode
    
    window = start_window.clone().detach() # make sure not to change orginal input
    preds = [] # predictions

    for _ in range(steps):
        with torch.no_grad():
            # LSTM expects input shape (batch_size, seq_len, features)
            pred = model(window.unsqueeze(0)) # Adds dimension to (seq_len, 1) to get correct shape: (1, seq_len, 1)
        
        preds.append(pred.item())

        # shift window
        window = torch.cat([window[1:], pred], dim=0) # removes oldest value and adds new prediction at the end

    return preds

# %%
class BaselineNN(nn.Module):
    def __init__(self, input_size=1, hidden_size=64, output_size=1):
        super().__init__()

        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(input_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, output_size),
            nn.Sigmoid() # since we normalized the data to [0,1]
        )

    def forward(self, x):
        x = self.flatten(x)
        out = self.linear_relu_stack(x)

        return out

# %%
results = []

# how many times to repeat each config
n_runs = 5


# hyperparameters to try
window_sizes = [16,24,32]
output_sizes = [1] # only 1-step prediction for now
hidden_sizes = [32,64]
epochs_list = [500,1000,2000]
learning_rates = [1e-4, 5e-4, 1e-3]

# create data
series_full = pd.Series(data['Xtrain'].flatten())
series_full = data_cleaning(series_full).values


# try all combinations of hyperparameters
for window_size, output_size, hidden_size, epochs, learning_rate in itertools.product(window_sizes, output_sizes, hidden_sizes, epochs_list, learning_rates):

    print(f"\nRunning: window={window_size}, output={output_size}, hidden={hidden_size}, epochs={epochs}, learning rate={learning_rate}")

    # store results across runs
    mae_1_list, mae_200_list = [], []
    mse_1_list, mse_200_list = [], []

    for run in range(n_runs): # repeat training multiple times to average evaluation
        print(f"  Run {run+1}/{n_runs}")

        # recreate dataset with current chosen window
        df = pd.Series(data['Xtrain'].flatten())
        df = data_cleaning(df)

        X, Y = zip(*slices(df, window_size))

        X = np.array(X).reshape(-1, window_size, 1)
        Y = np.array(Y).reshape(-1, output_size)

        split = int(0.8 * len(X))

        X_train, X_val = X[:split], X[split:]
        Y_train, Y_val = Y[:split], Y[split:]

        # Convert to PyTorch tensors
        X_train = torch.tensor(X_train, dtype=torch.float32)
        Y_train = torch.tensor(Y_train, dtype=torch.float32)
        X_val = torch.tensor(X_val, dtype=torch.float32)
        Y_val = torch.tensor(Y_val, dtype=torch.float32)

        # create model
        model = BaselineNN(input_size=window_size, hidden_size=hidden_size, output_size=output_size)
        criterion = nn.MSELoss()
        optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)


        #-------------------------------------------------
        # training
        #-------------------------------------------------
        for epoch in range(epochs):
            model.train()
            optimizer.zero_grad()
            pred = model(X_train)
            loss = criterion(pred, Y_train)
            loss.backward() # backpropagation
            optimizer.step() # update parameters
        #-------------------------------------------------


        #-------------------------------------------------
        # 1-step evaluation
        #-------------------------------------------------
        model.eval()
        with torch.no_grad():
            val_pred = model(X_val).numpy()
            y_true = Y_val.numpy()

        mae_1 = mean_absolute_error(y_true, val_pred)
        mse_1 = mean_squared_error(y_true, val_pred)
        #-------------------------------------------------


        #-------------------------------------------------
        # 200-step evaluation
        #-------------------------------------------------
        start_idx = split
        start_window = series_full[start_idx:start_idx+window_size]

        # determine max possible steps
        max_steps = len(series_full) - (start_idx + window_size)
        steps = min(200, max_steps)

        true_future = series_full[start_idx+window_size:start_idx+window_size+steps] # true values

        # convert start window to tensor
        start_tensor = torch.tensor(start_window.reshape(window_size, 1), dtype=torch.float32)

        preds = recursive_predict(model, start_tensor, steps) # predictions

        mae_200 = mean_absolute_error(true_future, preds)
        mse_200 = mean_squared_error(true_future, preds)
        #-------------------------------------------------

        # store per run results
        mae_1_list.append(mae_1)
        mae_200_list.append(mae_200)
        mse_1_list.append(mse_1)
        mse_200_list.append(mse_200)


    #-------------------------------------------------
    # store results
    #-------------------------------------------------
    results.append({
        "window": window_size,
        "hidden": hidden_size,
        "epochs": epochs,
        "learning_rate" : learning_rate,

        "mae_1_mean": np.mean(mae_1_list),
        "mae_1_std": np.std(mae_1_list),

        "mae_200_mean": np.mean(mae_200_list),
        "mae_200_std": np.std(mae_200_list),

        "mse_1_mean": np.mean(mse_1_list),
        "mse_200_mean": np.mean(mse_200_list)
    })
    #-------------------------------------------------


    print(f"Avg 1-step MAE: {np.mean(mae_1_list):.4f} +- {np.std(mae_1_list):.4f}")
    print(f"Avg {steps}-step MAE: {np.mean(mae_200_list):.4f} +- {np.std(mae_200_list):.4f}")

#-------------------------------------------------
# sort best models
results_sorted = sorted(results, key=lambda x: x["mae_200_mean"] + x["mae_200_std"])

print("\nTop 5 models (based on mean 200-step MAE):")
for r in results_sorted[:5]:
    print(r)
# Out:
# Running: window=16, output=1, hidden=32, epochs=500, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.1853 +- 0.0111
# Avg 197-step MAE: 0.1731 +- 0.0063
#
# Running: window=16, output=1, hidden=32, epochs=500, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0564 +- 0.0029
# Avg 197-step MAE: 0.1500 +- 0.0003
#
# Running: window=16, output=1, hidden=32, epochs=500, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0314 +- 0.0018
# Avg 197-step MAE: 0.1990 +- 0.0280
#
# Running: window=16, output=1, hidden=32, epochs=1000, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.1105 +- 0.0113
# Avg 197-step MAE: 0.1512 +- 0.0013
#
# Running: window=16, output=1, hidden=32, epochs=1000, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0335 +- 0.0036
# Avg 197-step MAE: 0.1819 +- 0.0205
#
# Running: window=16, output=1, hidden=32, epochs=1000, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0259 +- 0.0052
# Avg 197-step MAE: 0.1813 +- 0.0530
#
# Running: window=16, output=1, hidden=32, epochs=2000, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0626 +- 0.0061
# Avg 197-step MAE: 0.1494 +- 0.0004
#
# Running: window=16, output=1, hidden=32, epochs=2000, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0242 +- 0.0053
# Avg 197-step MAE: 0.1730 +- 0.0494
#
# Running: window=16, output=1, hidden=32, epochs=2000, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0125 +- 0.0037
# Avg 197-step MAE: 0.1684 +- 0.0599
#
# Running: window=16, output=1, hidden=64, epochs=500, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.1474 +- 0.0109
# Avg 197-step MAE: 0.1576 +- 0.0011
#
# Running: window=16, output=1, hidden=64, epochs=500, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0383 +- 0.0019
# Avg 197-step MAE: 0.1643 +- 0.0093
#
# Running: window=16, output=1, hidden=64, epochs=500, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0241 +- 0.0026
# Avg 197-step MAE: 0.2404 +- 0.0080
#
# Running: window=16, output=1, hidden=64, epochs=1000, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0970 +- 0.0059
# Avg 197-step MAE: 0.1499 +- 0.0004
#
# Running: window=16, output=1, hidden=64, epochs=1000, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0248 +- 0.0036
# Avg 197-step MAE: 0.2078 +- 0.0464
#
# Running: window=16, output=1, hidden=64, epochs=1000, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0118 +- 0.0024
# Avg 197-step MAE: 0.1849 +- 0.0483
#
# Running: window=16, output=1, hidden=64, epochs=2000, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0465 +- 0.0041
# Avg 197-step MAE: 0.1507 +- 0.0023
#
# Running: window=16, output=1, hidden=64, epochs=2000, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0126 +- 0.0043
# Avg 197-step MAE: 0.2102 +- 0.0331
#
# Running: window=16, output=1, hidden=64, epochs=2000, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0070 +- 0.0007
# Avg 197-step MAE: 0.1034 +- 0.0270
#
# Running: window=24, output=1, hidden=32, epochs=500, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.1679 +- 0.0180
# Avg 196-step MAE: 0.1638 +- 0.0083
#
# Running: window=24, output=1, hidden=32, epochs=500, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0513 +- 0.0093
# Avg 196-step MAE: 0.1555 +- 0.0055
#
# Running: window=24, output=1, hidden=32, epochs=500, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0370 +- 0.0013
# Avg 196-step MAE: 0.1763 +- 0.0035
#
# Running: window=24, output=1, hidden=32, epochs=1000, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0998 +- 0.0078
# Avg 196-step MAE: 0.1504 +- 0.0010
#
# Running: window=24, output=1, hidden=32, epochs=1000, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0348 +- 0.0010
# Avg 196-step MAE: 0.1575 +- 0.0148
#
# Running: window=24, output=1, hidden=32, epochs=1000, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0258 +- 0.0039
# Avg 196-step MAE: 0.1282 +- 0.0182
#
# Running: window=24, output=1, hidden=32, epochs=2000, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0639 +- 0.0030
# Avg 196-step MAE: 0.1504 +- 0.0004
#
# Running: window=24, output=1, hidden=32, epochs=2000, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0198 +- 0.0037
# Avg 196-step MAE: 0.1409 +- 0.0359
#
# Running: window=24, output=1, hidden=32, epochs=2000, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0103 +- 0.0017
# Avg 196-step MAE: 0.1619 +- 0.0202
#
# Running: window=24, output=1, hidden=64, epochs=500, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.1314 +- 0.0100
# Avg 196-step MAE: 0.1532 +- 0.0015
#
# Running: window=24, output=1, hidden=64, epochs=500, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0357 +- 0.0024
# Avg 196-step MAE: 0.1876 +- 0.0173
#
# Running: window=24, output=1, hidden=64, epochs=500, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0232 +- 0.0046
# Avg 196-step MAE: 0.1975 +- 0.0253
#
# Running: window=24, output=1, hidden=64, epochs=1000, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0700 +- 0.0039
# Avg 196-step MAE: 0.1503 +- 0.0007
#
# Running: window=24, output=1, hidden=64, epochs=1000, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0245 +- 0.0046
# Avg 196-step MAE: 0.1513 +- 0.0455
#
# Running: window=24, output=1, hidden=64, epochs=1000, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0105 +- 0.0011
# Avg 196-step MAE: 0.1581 +- 0.0394
#
# Running: window=24, output=1, hidden=64, epochs=2000, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0408 +- 0.0024
# Avg 196-step MAE: 0.1617 +- 0.0045
#
# Running: window=24, output=1, hidden=64, epochs=2000, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0108 +- 0.0019
# Avg 196-step MAE: 0.1160 +- 0.0504
#
# Running: window=24, output=1, hidden=64, epochs=2000, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0069 +- 0.0008
# Avg 196-step MAE: 0.1300 +- 0.0456
#
# Running: window=32, output=1, hidden=32, epochs=500, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.1494 +- 0.0092
# Avg 194-step MAE: 0.1559 +- 0.0022
#
# Running: window=32, output=1, hidden=32, epochs=500, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0413 +- 0.0025
# Avg 194-step MAE: 0.1679 +- 0.0069
#
# Running: window=32, output=1, hidden=32, epochs=500, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0361 +- 0.0020
# Avg 194-step MAE: 0.1475 +- 0.0093
#
# Running: window=32, output=1, hidden=32, epochs=1000, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0990 +- 0.0105
# Avg 194-step MAE: 0.1501 +- 0.0005
#
# Running: window=32, output=1, hidden=32, epochs=1000, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0313 +- 0.0039
# Avg 194-step MAE: 0.1355 +- 0.0268
#
# Running: window=32, output=1, hidden=32, epochs=1000, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0180 +- 0.0039
# Avg 194-step MAE: 0.1618 +- 0.0325
#
# Running: window=32, output=1, hidden=32, epochs=2000, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0549 +- 0.0037
# Avg 194-step MAE: 0.1556 +- 0.0026
#
# Running: window=32, output=1, hidden=32, epochs=2000, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0187 +- 0.0040
# Avg 194-step MAE: 0.1319 +- 0.0244
#
# Running: window=32, output=1, hidden=32, epochs=2000, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0098 +- 0.0019
# Avg 194-step MAE: 0.1665 +- 0.0411
#
# Running: window=32, output=1, hidden=64, epochs=500, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.1229 +- 0.0063
# Avg 194-step MAE: 0.1510 +- 0.0006
#
# Running: window=32, output=1, hidden=64, epochs=500, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0365 +- 0.0013
# Avg 194-step MAE: 0.1727 +- 0.0040
#
# Running: window=32, output=1, hidden=64, epochs=500, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0232 +- 0.0023
# Avg 194-step MAE: 0.1100 +- 0.0094
#
# Running: window=32, output=1, hidden=64, epochs=1000, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0762 +- 0.0058
# Avg 194-step MAE: 0.1515 +- 0.0012
#
# Running: window=32, output=1, hidden=64, epochs=1000, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0244 +- 0.0047
# Avg 194-step MAE: 0.1165 +- 0.0096
#
# Running: window=32, output=1, hidden=64, epochs=1000, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0105 +- 0.0022
# Avg 194-step MAE: 0.1157 +- 0.0250
#
# Running: window=32, output=1, hidden=64, epochs=2000, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0407 +- 0.0028
# Avg 194-step MAE: 0.1715 +- 0.0051
#
# Running: window=32, output=1, hidden=64, epochs=2000, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0144 +- 0.0032
# Avg 194-step MAE: 0.1258 +- 0.0232
#
# Running: window=32, output=1, hidden=64, epochs=2000, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0076 +- 0.0007
# Avg 194-step MAE: 0.1351 +- 0.0603
#
# Top 5 models (based on mean 200-step MAE):
# {'window': 32, 'hidden': 64, 'epochs': 500, 'learning_rate': 0.001, 'mae_1_mean': np.float64(0.023226279765367508), 'mae_1_std': np.float64(0.0023180268187884935), 'mae_200_mean': np.float64(0.10995481361614134), 'mae_200_std': np.float64(0.009386563111363162), 'mse_1_mean': np.float64(0.0008599160588346422), 'mse_200_mean': np.float64(0.021937947271605352)}
# {'window': 32, 'hidden': 64, 'epochs': 1000, 'learning_rate': 0.0005, 'mae_1_mean': np.float64(0.024358698353171348), 'mae_1_std': np.float64(0.00469924916866529), 'mae_200_mean': np.float64(0.11651899413367776), 'mae_200_std': np.float64(0.009595304562417596), 'mse_1_mean': np.float64(0.0009494799305684865), 'mse_200_mean': np.float64(0.02547577656081752)}
# {'window': 16, 'hidden': 64, 'epochs': 2000, 'learning_rate': 0.001, 'mae_1_mean': np.float64(0.007030900474637747), 'mae_1_std': np.float64(0.0006818030104470412), 'mae_200_mean': np.float64(0.10335200096035142), 'mae_200_std': np.float64(0.02702982941322752), 'mse_1_mean': np.float64(8.593001257395372e-05), 'mse_200_mean': np.float64(0.027366787256228993)}
# {'window': 32, 'hidden': 64, 'epochs': 1000, 'learning_rate': 0.001, 'mae_1_mean': np.float64(0.010497780423611403), 'mae_1_std': np.float64(0.002240579875354976), 'mae_200_mean': np.float64(0.11567097288753883), 'mae_200_std': np.float64(0.024967680909597657), 'mse_1_mean': np.float64(0.0002002126246225089), 'mse_200_mean': np.float64(0.033301787110966555)}
# {'window': 24, 'hidden': 32, 'epochs': 1000, 'learning_rate': 0.001, 'mae_1_mean': np.float64(0.025757688283920287), 'mae_1_std': np.float64(0.003893424763296877), 'mae_200_mean': np.float64(0.12823428209222593), 'mae_200_std': np.float64(0.01816735182952885), 'mse_1_mean': np.float64(0.0010403421125374734), 'mse_200_mean': np.float64(0.02863511932956886)}

# %%
# hyperparameters
window_size = 32
output_size = 1
hidden_size = 64
epochs = 1000
learning_rate = 1e-3
#---------------------------------------------------

# create data
series_full = pd.Series(data['Xtrain'].flatten())
series_full = data_cleaning(series_full).values

# recreate dataset with current chosen window
df = pd.Series(data['Xtrain'].flatten())
df = data_cleaning(df)

X, Y = zip(*slices(df, window_size))

X = np.array(X).reshape(-1, window_size, 1)
Y = np.array(Y).reshape(-1, 1)

split = int(0.8 * len(X))

X_train, X_val = X[:split], X[split:]
Y_train, Y_val = Y[:split], Y[split:]

# Convert to PyTorch tensors
X_train = torch.tensor(X_train, dtype=torch.float32)
Y_train = torch.tensor(Y_train, dtype=torch.float32)
X_val = torch.tensor(X_val, dtype=torch.float32)
Y_val = torch.tensor(Y_val, dtype=torch.float32)

# create model
model = BaselineNN(input_size=window_size, hidden_size=hidden_size, output_size=1)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)


#-------------------------------------------------
# training
#-------------------------------------------------
for epoch in range(epochs):
    model.train()
    optimizer.zero_grad()
    pred = model(X_train)
    loss = criterion(pred, Y_train)
    loss.backward() # backpropagation
    optimizer.step() # update parameters
#-------------------------------------------------


#-------------------------------------------------
# 200-step evaluation
#-------------------------------------------------
start_idx = split
start_window = series_full[start_idx:start_idx+window_size]

# determine max possible steps
max_steps = len(series_full) - (start_idx + window_size)
steps = min(200, max_steps)

true_future = series_full[start_idx+window_size:start_idx+window_size+steps] # true values

# convert start window to tensor
start_tensor = torch.tensor(start_window.reshape(window_size, 1), dtype=torch.float32)

preds = recursive_predict(model, start_tensor, steps) # predictions

mae_200 = mean_absolute_error(true_future, preds)
mse_200 = mean_squared_error(true_future, preds)

print(f"\n{steps}-step MAE: {mae_200:.4f}")
print(f"\n{steps}-step MSE: {mse_200:.4f}")

#-----------------------
# plot
#-----------------------
import matplotlib.pyplot as plt

# Create x-axis (time steps)
t = range(len(true_future))

plt.figure(figsize=(12, 5))

# True signal
plt.plot(t, true_future, label="True values", linewidth=2)

# Predicted signal
plt.plot(t, preds, label="Predictions", linestyle='--')

plt.title("200-step Recursive Prediction vs True Signal")
plt.xlabel("Time step")
plt.ylabel("Normalized value")
plt.legend()

plt.show()
# Out:
# 194-step MAE: 0.0473
#
# 194-step MSE: 0.0043
