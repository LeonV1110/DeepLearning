# %%
# Imports
from scipy.io import loadmat
import pandas as pd
import numpy as np
import plotly.express as px
import torch.nn as nn
import torch
import itertools
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
data = loadmat('Xtrain.mat')

# %%
def data_cleaning(df: pd.DataFrame) -> pd.DataFrame:
    normalized = df/255
    return normalized
    
def slices(s: pd.Series, slice_length) -> tuple[pd.Series, pd.Series]:
    slices = [window for window in s.rolling(window=slice_length+1)]
    res = [(slc.iloc[:-1], slc.iloc[-1]) for slc in slices[slice_length:]]
    return res

# %%
def recursive_predict(model, start_window, steps=200):
    model.eval() # set model to evaluation mode
    
    window = start_window.clone().detach() # make sure not to change orginal input
    preds = [] # predictions

    for _ in range(steps):
        with torch.no_grad():
            # LSTM expects input shape (batch_size, seq_len, features)
            pred = model(window.unsqueeze(0)) # Adds dimension to (seq_len, 1) to get correct shape: (1, seq_len, 1)
        
        preds.append(pred.item())

        # shift window
        window = torch.cat([window[1:], pred], dim=0) # removes oldest value and adds new prediction at the end

    return preds

# %%
class LSTMModel(nn.Module):
    def __init__(self, input_size=1, hidden_size=64, num_layers=2):
        super().__init__()
        
        self.lstm = nn.LSTM(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            batch_first=True # needed because we have (batch_size, seq_len, 1). So batch size is given first
        )
        
        self.fc = nn.Linear(hidden_size, 1) # Connects final layer to output

    def forward(self, x):
        # x shape: (batch_size, seq_len, input_size)

        # pass through model
        out, _ = self.lstm(x)

        # out contains hidden states for all timesteps:
        # shape: (batch_size, seq_len, hidden_size)
        
        # we only care about last timestep.
        out = out[:, -1, :] #takes last timestep
        out = self.fc(out) # gets prediction
        
        return out

# %%
results = []

# how many times to repeat each config
n_runs = 5

# hyperparameters to try
window_sizes = [16,24,32]
hidden_sizes = [32,64]
num_layers_list = [1,2]
epochs_list = [500,1000,2000]
learning_rates = [1e-4, 5e-4, 1e-3]

# create data
series_full = pd.Series(data['Xtrain'].flatten())
series_full = data_cleaning(series_full).values


# try all combinations of hyperparameters
for window_size, hidden_size, num_layers, epochs, learning_rate in itertools.product(window_sizes, hidden_sizes, num_layers_list, epochs_list, learning_rates):

    print(f"\nRunning: window={window_size}, hidden={hidden_size}, layers={num_layers}, epochs={epochs}, learning rate={learning_rate}")

    # store results across runs
    mae_1_list, mae_200_list = [], []
    mse_1_list, mse_200_list = [], []

    for run in range(n_runs): # repeat training multiple times to average evaluation
        print(f"  Run {run+1}/{n_runs}")

        # recreate dataset with current chosen window
        df = pd.Series(data['Xtrain'].flatten())
        df = data_cleaning(df)

        X, Y = zip(*slices(df, window_size))

        X = np.array(X).reshape(-1, window_size, 1)
        Y = np.array(Y).reshape(-1, 1)

        split = int(0.8 * len(X))

        X_train, X_val = X[:split], X[split:]
        Y_train, Y_val = Y[:split], Y[split:]

        # Convert to PyTorch tensors
        X_train = torch.tensor(X_train, dtype=torch.float32)
        Y_train = torch.tensor(Y_train, dtype=torch.float32)
        X_val = torch.tensor(X_val, dtype=torch.float32)
        Y_val = torch.tensor(Y_val, dtype=torch.float32)

        # create model
        model = LSTMModel(hidden_size=hidden_size, num_layers=num_layers)
        criterion = nn.MSELoss()
        optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)


        #-------------------------------------------------
        # training
        #-------------------------------------------------
        for epoch in range(epochs):
            model.train()
            optimizer.zero_grad()
            pred = model(X_train)
            loss = criterion(pred, Y_train)
            loss.backward() # backpropagation
            optimizer.step() # update parameters
        #-------------------------------------------------


        #-------------------------------------------------
        # 1-step evaluation
        #-------------------------------------------------
        model.eval()
        with torch.no_grad():
            val_pred = model(X_val).numpy()
            y_true = Y_val.numpy()

        mae_1 = mean_absolute_error(y_true, val_pred)
        mse_1 = mean_squared_error(y_true, val_pred)
        #-------------------------------------------------


        #-------------------------------------------------
        # 200-step evaluation
        #-------------------------------------------------
        start_idx = split
        start_window = series_full[start_idx:start_idx+window_size]

        # determine max possible steps
        max_steps = len(series_full) - (start_idx + window_size)
        steps = min(200, max_steps)

        true_future = series_full[start_idx+window_size:start_idx+window_size+steps] # true values

        # convert start window to tensor
        start_tensor = torch.tensor(start_window.reshape(window_size, 1), dtype=torch.float32)

        preds = recursive_predict(model, start_tensor, steps) # predictions

        mae_200 = mean_absolute_error(true_future, preds)
        mse_200 = mean_squared_error(true_future, preds)
        #-------------------------------------------------

        # store per run results
        mae_1_list.append(mae_1)
        mae_200_list.append(mae_200)
        mse_1_list.append(mse_1)
        mse_200_list.append(mse_200)


    #-------------------------------------------------
    # store results
    #-------------------------------------------------
    results.append({
        "window": window_size,
        "hidden": hidden_size,
        "layers": num_layers,
        "epochs": epochs,
        "learning_rate" : learning_rate,

        "mae_1_mean": np.mean(mae_1_list),
        "mae_1_std": np.std(mae_1_list),

        "mae_200_mean": np.mean(mae_200_list),
        "mae_200_std": np.std(mae_200_list),

        "mse_1_mean": np.mean(mse_1_list),
        "mse_200_mean": np.mean(mse_200_list)
    })
    #-------------------------------------------------


    print(f"Avg 1-step MAE: {np.mean(mae_1_list):.4f} +- {np.std(mae_1_list):.4f}")
    print(f"Avg {steps}-step MAE: {np.mean(mae_200_list):.4f} +- {np.std(mae_200_list):.4f}")

#-------------------------------------------------
# sort best models
results_sorted = sorted(results, key=lambda x: x["mae_200_mean"] + x["mae_200_std"])

print("\nTop 5 models (based on mean 200-step MAE):")
for r in results_sorted[:5]:
    print(r)
# Out:
# Running: window=16, hidden=32, layers=1, epochs=500, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.1437 +- 0.0022
# Avg 197-step MAE: 0.1492 +- 0.0001
#
# Running: window=16, hidden=32, layers=1, epochs=500, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0285 +- 0.0149
# Avg 197-step MAE: 0.2049 +- 0.0343
#
# Running: window=16, hidden=32, layers=1, epochs=500, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0090 +- 0.0024
# Avg 197-step MAE: 0.1191 +- 0.0145
#
# Running: window=16, hidden=32, layers=1, epochs=1000, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.1224 +- 0.0324
# Avg 197-step MAE: 0.1487 +- 0.0011
#
# Running: window=16, hidden=32, layers=1, epochs=1000, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0075 +- 0.0029
# Avg 197-step MAE: 0.1236 +- 0.0236
#
# Running: window=16, hidden=32, layers=1, epochs=1000, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0062 +- 0.0013
# Avg 197-step MAE: 0.1563 +- 0.0405
#
# Running: window=16, hidden=32, layers=1, epochs=2000, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0183 +- 0.0174
# Avg 197-step MAE: 0.1272 +- 0.0639
#
# Running: window=16, hidden=32, layers=1, epochs=2000, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0048 +- 0.0006
# Avg 197-step MAE: 0.1005 +- 0.0663
#
# Running: window=16, hidden=32, layers=1, epochs=2000, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0044 +- 0.0006
# Avg 197-step MAE: 0.1278 +- 0.0421
#
# Running: window=16, hidden=32, layers=2, epochs=500, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.1281 +- 0.0376
# Avg 197-step MAE: 0.1494 +- 0.0005
#
# Running: window=16, hidden=32, layers=2, epochs=500, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0158 +- 0.0070
# Avg 197-step MAE: 0.1270 +- 0.0620
#
# Running: window=16, hidden=32, layers=2, epochs=500, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0078 +- 0.0024
# Avg 197-step MAE: 0.1055 +- 0.0486
#
# Running: window=16, hidden=32, layers=2, epochs=1000, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.1045 +- 0.0470
# Avg 197-step MAE: 0.1517 +- 0.0066
#
# Running: window=16, hidden=32, layers=2, epochs=1000, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0046 +- 0.0006
# Avg 197-step MAE: 0.0816 +- 0.0430
#
# Running: window=16, hidden=32, layers=2, epochs=1000, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0045 +- 0.0010
# Avg 197-step MAE: 0.1065 +- 0.0252
#
# Running: window=16, hidden=32, layers=2, epochs=2000, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0102 +- 0.0052
# Avg 197-step MAE: 0.1123 +- 0.0621
#
# Running: window=16, hidden=32, layers=2, epochs=2000, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0044 +- 0.0006
# Avg 197-step MAE: 0.0620 +- 0.0380
#
# Running: window=16, hidden=32, layers=2, epochs=2000, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0040 +- 0.0005
# Avg 197-step MAE: 0.0895 +- 0.0239
#
# Running: window=16, hidden=64, layers=1, epochs=500, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.1443 +- 0.0016
# Avg 197-step MAE: 0.1492 +- 0.0000
#
# Running: window=16, hidden=64, layers=1, epochs=500, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0101 +- 0.0021
# Avg 197-step MAE: 0.0957 +- 0.0279
#
# Running: window=16, hidden=64, layers=1, epochs=500, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0081 +- 0.0015
# Avg 197-step MAE: 0.1149 +- 0.0275
#
# Running: window=16, hidden=64, layers=1, epochs=1000, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0575 +- 0.0185
# Avg 197-step MAE: 0.1551 +- 0.0135
#
# Running: window=16, hidden=64, layers=1, epochs=1000, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0065 +- 0.0018
# Avg 197-step MAE: 0.0885 +- 0.0561
#
# Running: window=16, hidden=64, layers=1, epochs=1000, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0051 +- 0.0007
# Avg 197-step MAE: 0.1415 +- 0.0311
#
# Running: window=16, hidden=64, layers=1, epochs=2000, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0078 +- 0.0017
# Avg 197-step MAE: 0.1427 +- 0.0543
#
# Running: window=16, hidden=64, layers=1, epochs=2000, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0043 +- 0.0005
# Avg 197-step MAE: 0.0822 +- 0.0545
#
# Running: window=16, hidden=64, layers=1, epochs=2000, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0049 +- 0.0008
# Avg 197-step MAE: 0.1066 +- 0.0490
#
# Running: window=16, hidden=64, layers=2, epochs=500, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.1035 +- 0.0395
# Avg 197-step MAE: 0.1514 +- 0.0025
#
# Running: window=16, hidden=64, layers=2, epochs=500, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0077 +- 0.0011
# Avg 197-step MAE: 0.1039 +- 0.0272
#
# Running: window=16, hidden=64, layers=2, epochs=500, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0053 +- 0.0003
# Avg 197-step MAE: 0.0960 +- 0.0425
#
# Running: window=16, hidden=64, layers=2, epochs=1000, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0355 +- 0.0184
# Avg 197-step MAE: 0.1520 +- 0.0158
#
# Running: window=16, hidden=64, layers=2, epochs=1000, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0051 +- 0.0011
# Avg 197-step MAE: 0.0946 +- 0.0346
#
# Running: window=16, hidden=64, layers=2, epochs=1000, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0045 +- 0.0008
# Avg 197-step MAE: 0.1193 +- 0.0318
#
# Running: window=16, hidden=64, layers=2, epochs=2000, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0049 +- 0.0010
# Avg 197-step MAE: 0.0933 +- 0.0517
#
# Running: window=16, hidden=64, layers=2, epochs=2000, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0043 +- 0.0016
# Avg 197-step MAE: 0.1119 +- 0.0252
#
# Running: window=16, hidden=64, layers=2, epochs=2000, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0037 +- 0.0005
# Avg 197-step MAE: 0.0499 +- 0.0277
#
# Running: window=24, hidden=32, layers=1, epochs=500, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.1476 +- 0.0015
# Avg 196-step MAE: 0.1497 +- 0.0001
#
# Running: window=24, hidden=32, layers=1, epochs=500, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0357 +- 0.0188
# Avg 196-step MAE: 0.1511 +- 0.0372
#
# Running: window=24, hidden=32, layers=1, epochs=500, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0132 +- 0.0040
# Avg 196-step MAE: 0.1565 +- 0.0266
#
# Running: window=24, hidden=32, layers=1, epochs=1000, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.1125 +- 0.0364
# Avg 196-step MAE: 0.1484 +- 0.0031
#
# Running: window=24, hidden=32, layers=1, epochs=1000, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0118 +- 0.0070
# Avg 196-step MAE: 0.1402 +- 0.0806
#
# Running: window=24, hidden=32, layers=1, epochs=1000, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0062 +- 0.0017
# Avg 196-step MAE: 0.1046 +- 0.0374
#
# Running: window=24, hidden=32, layers=1, epochs=2000, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0586 +- 0.0193
# Avg 196-step MAE: 0.1859 +- 0.0291
#
# Running: window=24, hidden=32, layers=1, epochs=2000, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0056 +- 0.0014
# Avg 196-step MAE: 0.0817 +- 0.0288
#
# Running: window=24, hidden=32, layers=1, epochs=2000, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0046 +- 0.0008
# Avg 196-step MAE: 0.1044 +- 0.0373
#
# Running: window=24, hidden=32, layers=2, epochs=500, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.1300 +- 0.0374
# Avg 196-step MAE: 0.1499 +- 0.0005
#
# Running: window=24, hidden=32, layers=2, epochs=500, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0075 +- 0.0012
# Avg 196-step MAE: 0.0917 +- 0.0317
#
# Running: window=24, hidden=32, layers=2, epochs=500, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0061 +- 0.0013
# Avg 196-step MAE: 0.1148 +- 0.0471
#
# Running: window=24, hidden=32, layers=2, epochs=1000, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.1245 +- 0.0373
# Avg 196-step MAE: 0.1471 +- 0.0053
#
# Running: window=24, hidden=32, layers=2, epochs=1000, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0067 +- 0.0013
# Avg 196-step MAE: 0.0837 +- 0.0551
#
# Running: window=24, hidden=32, layers=2, epochs=1000, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0044 +- 0.0005
# Avg 196-step MAE: 0.0857 +- 0.0427
#
# Running: window=24, hidden=32, layers=2, epochs=2000, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0104 +- 0.0047
# Avg 196-step MAE: 0.1711 +- 0.0347
#
# Running: window=24, hidden=32, layers=2, epochs=2000, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0043 +- 0.0004
# Avg 196-step MAE: 0.0615 +- 0.0443
#
# Running: window=24, hidden=32, layers=2, epochs=2000, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0039 +- 0.0005
# Avg 196-step MAE: 0.0596 +- 0.0367
#
# Running: window=24, hidden=64, layers=1, epochs=500, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.1100 +- 0.0417
# Avg 196-step MAE: 0.1505 +- 0.0009
#
# Running: window=24, hidden=64, layers=1, epochs=500, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0126 +- 0.0030
# Avg 196-step MAE: 0.1423 +- 0.0375
#
# Running: window=24, hidden=64, layers=1, epochs=500, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0097 +- 0.0025
# Avg 196-step MAE: 0.1413 +- 0.0478
#
# Running: window=24, hidden=64, layers=1, epochs=1000, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0550 +- 0.0014
# Avg 196-step MAE: 0.1491 +- 0.0010
#
# Running: window=24, hidden=64, layers=1, epochs=1000, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0079 +- 0.0014
# Avg 196-step MAE: 0.1173 +- 0.0488
#
# Running: window=24, hidden=64, layers=1, epochs=1000, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0056 +- 0.0020
# Avg 196-step MAE: 0.1317 +- 0.0175
#
# Running: window=24, hidden=64, layers=1, epochs=2000, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0100 +- 0.0013
# Avg 196-step MAE: 0.1757 +- 0.0462
#
# Running: window=24, hidden=64, layers=1, epochs=2000, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0043 +- 0.0009
# Avg 196-step MAE: 0.0968 +- 0.0336
#
# Running: window=24, hidden=64, layers=1, epochs=2000, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0039 +- 0.0004
# Avg 196-step MAE: 0.0742 +- 0.0402
#
# Running: window=24, hidden=64, layers=2, epochs=500, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.1270 +- 0.0365
# Avg 196-step MAE: 0.1502 +- 0.0010
#
# Running: window=24, hidden=64, layers=2, epochs=500, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0077 +- 0.0020
# Avg 196-step MAE: 0.1184 +- 0.0329
#
# Running: window=24, hidden=64, layers=2, epochs=500, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0058 +- 0.0006
# Avg 196-step MAE: 0.1344 +- 0.0106
#
# Running: window=24, hidden=64, layers=2, epochs=1000, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0274 +- 0.0144
# Avg 196-step MAE: 0.1275 +- 0.0506
#
# Running: window=24, hidden=64, layers=2, epochs=1000, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0045 +- 0.0003
# Avg 196-step MAE: 0.1137 +- 0.0438
#
# Running: window=24, hidden=64, layers=2, epochs=1000, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0046 +- 0.0007
# Avg 196-step MAE: 0.0794 +- 0.0417
#
# Running: window=24, hidden=64, layers=2, epochs=2000, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0047 +- 0.0007
# Avg 196-step MAE: 0.0896 +- 0.0137
#
# Running: window=24, hidden=64, layers=2, epochs=2000, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0046 +- 0.0007
# Avg 196-step MAE: 0.0971 +- 0.0370
#
# Running: window=24, hidden=64, layers=2, epochs=2000, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0055 +- 0.0017
# Avg 196-step MAE: 0.0944 +- 0.0427
#
# Running: window=32, hidden=32, layers=1, epochs=500, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.1462 +- 0.0030
# Avg 194-step MAE: 0.1493 +- 0.0001
#
# Running: window=32, hidden=32, layers=1, epochs=500, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0324 +- 0.0170
# Avg 194-step MAE: 0.1636 +- 0.0554
#
# Running: window=32, hidden=32, layers=1, epochs=500, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0121 +- 0.0033
# Avg 194-step MAE: 0.1350 +- 0.0238
#
# Running: window=32, hidden=32, layers=1, epochs=1000, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.1047 +- 0.0438
# Avg 194-step MAE: 0.1487 +- 0.0037
#
# Running: window=32, hidden=32, layers=1, epochs=1000, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0102 +- 0.0018
# Avg 194-step MAE: 0.1294 +- 0.0483
#
# Running: window=32, hidden=32, layers=1, epochs=1000, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0072 +- 0.0021
# Avg 194-step MAE: 0.0851 +- 0.0444
#
# Running: window=32, hidden=32, layers=1, epochs=2000, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0458 +- 0.0103
# Avg 194-step MAE: 0.1815 +- 0.0298
#
# Running: window=32, hidden=32, layers=1, epochs=2000, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0067 +- 0.0019
# Avg 194-step MAE: 0.1756 +- 0.1742
#
# Running: window=32, hidden=32, layers=1, epochs=2000, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0048 +- 0.0008
# Avg 194-step MAE: 0.0956 +- 0.0375
#
# Running: window=32, hidden=32, layers=2, epochs=500, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.1295 +- 0.0377
# Avg 194-step MAE: 0.1501 +- 0.0014
#
# Running: window=32, hidden=32, layers=2, epochs=500, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0319 +- 0.0454
# Avg 194-step MAE: 0.1209 +- 0.0234
#
# Running: window=32, hidden=32, layers=2, epochs=500, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0072 +- 0.0011
# Avg 194-step MAE: 0.1321 +- 0.0452
#
# Running: window=32, hidden=32, layers=2, epochs=1000, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0703 +- 0.0377
# Avg 194-step MAE: 0.1639 +- 0.0244
#
# Running: window=32, hidden=32, layers=2, epochs=1000, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0057 +- 0.0006
# Avg 194-step MAE: 0.1007 +- 0.0354
#
# Running: window=32, hidden=32, layers=2, epochs=1000, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0068 +- 0.0036
# Avg 194-step MAE: 0.1164 +- 0.0519
#
# Running: window=32, hidden=32, layers=2, epochs=2000, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0099 +- 0.0029
# Avg 194-step MAE: 0.0935 +- 0.0288
#
# Running: window=32, hidden=32, layers=2, epochs=2000, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0056 +- 0.0015
# Avg 194-step MAE: 0.0769 +- 0.0523
#
# Running: window=32, hidden=32, layers=2, epochs=2000, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0040 +- 0.0002
# Avg 194-step MAE: 0.0475 +- 0.0337
#
# Running: window=32, hidden=64, layers=1, epochs=500, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.1218 +- 0.0322
# Avg 194-step MAE: 0.1498 +- 0.0006
#
# Running: window=32, hidden=64, layers=1, epochs=500, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0152 +- 0.0068
# Avg 194-step MAE: 0.1257 +- 0.0157
#
# Running: window=32, hidden=64, layers=1, epochs=500, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0180 +- 0.0206
# Avg 194-step MAE: 0.1157 +- 0.0368
#
# Running: window=32, hidden=64, layers=1, epochs=1000, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0465 +- 0.0150
# Avg 194-step MAE: 0.1688 +- 0.0250
#
# Running: window=32, hidden=64, layers=1, epochs=1000, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0068 +- 0.0013
# Avg 194-step MAE: 0.1031 +- 0.0393
#
# Running: window=32, hidden=64, layers=1, epochs=1000, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0108 +- 0.0061
# Avg 194-step MAE: 0.1759 +- 0.0397
#
# Running: window=32, hidden=64, layers=1, epochs=2000, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0111 +- 0.0049
# Avg 194-step MAE: 0.1201 +- 0.0484
#
# Running: window=32, hidden=64, layers=1, epochs=2000, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0074 +- 0.0031
# Avg 194-step MAE: 0.1481 +- 0.0564
#
# Running: window=32, hidden=64, layers=1, epochs=2000, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0097 +- 0.0069
# Avg 194-step MAE: 0.0907 +- 0.0509
#
# Running: window=32, hidden=64, layers=2, epochs=500, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.1106 +- 0.0384
# Avg 194-step MAE: 0.1503 +- 0.0012
#
# Running: window=32, hidden=64, layers=2, epochs=500, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0074 +- 0.0020
# Avg 194-step MAE: 0.1190 +- 0.0223
#
# Running: window=32, hidden=64, layers=2, epochs=500, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0072 +- 0.0027
# Avg 194-step MAE: 0.1316 +- 0.0391
#
# Running: window=32, hidden=64, layers=2, epochs=1000, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0262 +- 0.0191
# Avg 194-step MAE: 0.1325 +- 0.0356
#
# Running: window=32, hidden=64, layers=2, epochs=1000, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0050 +- 0.0010
# Avg 194-step MAE: 0.0886 +- 0.0538
#
# Running: window=32, hidden=64, layers=2, epochs=1000, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0060 +- 0.0014
# Avg 194-step MAE: 0.0991 +- 0.0554
#
# Running: window=32, hidden=64, layers=2, epochs=2000, learning rate=0.0001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0058 +- 0.0010
# Avg 194-step MAE: 0.0634 +- 0.0181
#
# Running: window=32, hidden=64, layers=2, epochs=2000, learning rate=0.0005
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0040 +- 0.0006
# Avg 194-step MAE: 0.0679 +- 0.0403
#
# Running: window=32, hidden=64, layers=2, epochs=2000, learning rate=0.001
#   Run 1/5
#   Run 2/5
#   Run 3/5
#   Run 4/5
#   Run 5/5
# Avg 1-step MAE: 0.0050 +- 0.0015
# Avg 194-step MAE: 0.0818 +- 0.0411
#
# Top 5 models (based on mean 200-step MAE):
# {'window': 16, 'hidden': 64, 'layers': 2, 'epochs': 2000, 'learning_rate': 0.001, 'mae_1_mean': np.float64(0.003738472145050764), 'mae_1_std': np.float64(0.00047580988425670524), 'mae_200_mean': np.float64(0.049872153623475836), 'mae_200_std': np.float64(0.027731390565608565), 'mse_1_mean': np.float64(2.1913203090662138e-05), 'mse_200_mean': np.float64(0.01044957924729889)}
# {'window': 32, 'hidden': 32, 'layers': 2, 'epochs': 2000, 'learning_rate': 0.001, 'mae_1_mean': np.float64(0.004012242890894413), 'mae_1_std': np.float64(0.00019722686671937642), 'mae_200_mean': np.float64(0.047533993844160516), 'mae_200_std': np.float64(0.03367193458206948), 'mse_1_mean': np.float64(2.429909509373829e-05), 'mse_200_mean': np.float64(0.010497276051660497)}
# {'window': 32, 'hidden': 64, 'layers': 2, 'epochs': 2000, 'learning_rate': 0.0001, 'mae_1_mean': np.float64(0.005814823787659407), 'mae_1_std': np.float64(0.0010247293493038094), 'mae_200_mean': np.float64(0.06337285231551137), 'mae_200_std': np.float64(0.018114871538937146), 'mse_1_mean': np.float64(5.7386558910366145e-05), 'mse_200_mean': np.float64(0.01373474191298984)}
# {'window': 24, 'hidden': 32, 'layers': 2, 'epochs': 2000, 'learning_rate': 0.001, 'mae_1_mean': np.float64(0.0038670651614665986), 'mae_1_std': np.float64(0.00047887844581462), 'mae_200_mean': np.float64(0.059608720978107065), 'mae_200_std': np.float64(0.03674087636691593), 'mse_1_mean': np.float64(2.407505198789295e-05), 'mse_200_mean': np.float64(0.014528113397735316)}
# {'window': 16, 'hidden': 32, 'layers': 2, 'epochs': 2000, 'learning_rate': 0.0005, 'mae_1_mean': np.float64(0.004444089066237211), 'mae_1_std': np.float64(0.0005525706155539303), 'mae_200_mean': np.float64(0.06203034122418595), 'mae_200_std': np.float64(0.0379694838930694), 'mse_1_mean': np.float64(3.137538187729661e-05), 'mse_200_mean': np.float64(0.015472342403587382)}

# %%
# hyperparameters
window_size = 16
hidden_size = 32
num_layers = 2
epochs = 2000
learning_rate = 1e-3
#---------------------------------------------------

# create data
series_full = pd.Series(data['Xtrain'].flatten())
series_full = data_cleaning(series_full).values

# recreate dataset with current chosen window
df = pd.Series(data['Xtrain'].flatten())
df = data_cleaning(df)

X, Y = zip(*slices(df, window_size))

X = np.array(X).reshape(-1, window_size, 1)
Y = np.array(Y).reshape(-1, 1)

split = int(0.8 * len(X))

X_train, X_val = X[:split], X[split:]
Y_train, Y_val = Y[:split], Y[split:]

# Convert to PyTorch tensors
X_train = torch.tensor(X_train, dtype=torch.float32)
Y_train = torch.tensor(Y_train, dtype=torch.float32)
X_val = torch.tensor(X_val, dtype=torch.float32)
Y_val = torch.tensor(Y_val, dtype=torch.float32)

# create model
model = LSTMModel(hidden_size=hidden_size, num_layers=num_layers)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)


#-------------------------------------------------
# training
#-------------------------------------------------
for epoch in range(epochs):
    model.train()
    optimizer.zero_grad()
    pred = model(X_train)
    loss = criterion(pred, Y_train)
    loss.backward() # backpropagation
    optimizer.step() # update parameters
#-------------------------------------------------


#-------------------------------------------------
# 200-step evaluation
#-------------------------------------------------
start_idx = split
start_window = series_full[start_idx:start_idx+window_size]

# determine max possible steps
max_steps = len(series_full) - (start_idx + window_size)
steps = min(200, max_steps)

true_future = series_full[start_idx+window_size:start_idx+window_size+steps] # true values

# convert start window to tensor
start_tensor = torch.tensor(start_window.reshape(window_size, 1), dtype=torch.float32)

preds = recursive_predict(model, start_tensor, steps) # predictions

mae_200 = mean_absolute_error(true_future, preds)
mse_200 = mean_squared_error(true_future, preds)

print(f"\n{steps}-step MAE: {mae_200:.4f}")
print(f"\n{steps}-step MSE: {mse_200:.4f}")

#-----------------------
# plot
#-----------------------
import matplotlib.pyplot as plt

# Create x-axis (time steps)
t = range(len(true_future))

plt.figure(figsize=(12, 5))

# True signal
plt.plot(t, true_future, label="True values", linewidth=2)

# Predicted signal
plt.plot(t, preds, label="Predictions", linestyle='--')

plt.title("200-step Recursive Prediction vs True Signal")
plt.xlabel("Time step")
plt.ylabel("Normalized value")
plt.legend()

plt.show()
# Out:
# 197-step MAE: 0.0096
#
# 197-step MSE: 0.0002
